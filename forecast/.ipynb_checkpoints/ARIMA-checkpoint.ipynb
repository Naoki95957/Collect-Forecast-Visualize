# %% [markdown]
# # Time Series Forecasting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from datetime import datetime

# %%
# statsmodels required to use the ARIMA model
# pip install statsmodels
from statsmodels.tsa.arima.model import ARIMA
# scikit-learn required for performance metrics
# pip install scipy
# pip install scikit-learn
from sklearn.metrics import mean_squared_error

# %% [markdown]
# We will use a basic **ARIMA** model:
# * Autoregression
# * Integrated
# * Moving Average

# %% [markdown]
# # Data Preparation

# %% [markdown]
# This data has been pre-prepared for modeling:
# * continuous
# * does not contain nan values

# %%
df = pickle.load(open('assets/df.p', 'rb'))

# %%
df.head()
# Out:
#                      Biomass  Geothermal  HydroElectric  Thermal  Solar  Wind
# Date
# 2016-12-27 00:00:00   105.04      178.45           0.41   104.51   3.06  0.49
# 2016-12-27 01:00:00   103.92      178.71           0.41    84.67   3.06  0.49
# 2016-12-27 02:00:00   103.38      177.92           0.40    73.57   3.06  0.49
# 2016-12-27 03:00:00   102.66      177.99           0.40    73.19   3.06  0.49
# 2016-12-27 04:00:00   102.33      179.00           0.40    83.59   3.06  0.49

# %% [markdown]
# ## <span style="color:cyan">Visulaizing the Data</span>

# %% [markdown]
# We want to better visulaize the seasonality and overall trend in the
# data. This way we can make decisions on how to prep and model it.
# Since we have a large amount of data (almost 4 years) we will use a
# rolling average with a window of 2 weeks (14 days).

# %%
rolling_avg = df.rolling(window = 336).mean()

# %%
# plot ALL the data
fig, ax = plt.subplots(figsize = (20,6))
for energy in rolling_avg.columns:
    ax.plot(rolling_avg[energy], label=energy)
ax.legend()
ax.set_xlabel('Date')
ax.set_ylabel('Generation (GWh)')
ax.set_title('Electrical Generation for El Salvador')
# Out:
# Text(0.5, 1.0, 'Electrical Generation for El Salvador')

# %% [markdown]
# ## <span style="color:cyan">Examples of Seasonality and Trend</span>

# %%
# biomass is seasonal
fig, ax = plt.subplots(figsize = (10,3))
ax.plot(rolling_avg['Biomass'], color='tab:blue')
ax.set_xlabel('Date')
ax.set_ylabel('Generation (GWh)')
ax.set_title('Biomass Generation for El Salvador')
# Out:
# Text(0.5, 1.0, 'Biomass Generation for El Salvador')

# %%
# solar is increasing
fig, ax = plt.subplots(figsize = (10,3))
ax.plot(rolling_avg['Solar'], color='tab:purple')
ax.set_xlabel('Date')
ax.set_ylabel('Generation (GWh)')
ax.set_title('Solar Generation for El Salvador')
# Out:
# Text(0.5, 1.0, 'Solar Generation for El Salvador')

# %% [markdown]
# ## <span style="color:cyan">Sationarizing the Data</span>

# %% [markdown]
# To stationarize the data we will use first order differencing. This is
# essentially the same as taking the first derivative of the data.
# $\Large y_{t} = y_{t} - y_{t-1}$
#
# Assuming first order differencing is enough, the result should look
# like "white noise".

# %%
# detrend by taking 1st derivative
df_deriv = df - df.shift(1)
# remove first entry (nan)
df_deriv = df_deriv[1:]

# %%
fig, ax = plt.subplots(figsize = (10,3))
ax.plot(df_deriv['HydroElectric'], color='tab:green')
ax.set_xlabel('Date')
ax.set_ylabel('dy/dx')
ax.set_title('HydroElectric Energy (Stationary)')
# Out:
# Text(0.5, 1.0, 'HydroElectric Energy (Stationary)')

# %% [markdown]
# # Modeling

# %% [markdown]
# ARIMA(p,d,q)
# * p: lag order of autoregression
# * d: degree of differencing
# * q: order of error lags for moving average
#
# **Goal**: we will try to predict the HydroElectric energy for january
# 1st, 2020, using the past 3 years as training data.

# %%
train = df['HydroElectric']['2017-01-01':'2019-12-31'].tolist()
test = df['HydroElectric']['2020-01-01':'2020-01-01'].tolist()

# %% [markdown]
# ## <span style="color:cyan">ARIMA(1,1,1)</span>

# %%
# walk-forward validation
predictions = list()
history = train.copy()
for t in range(len(test)):
    # fit model
    model = ARIMA(history, order=(1,1,1)).fit()
    
    # get forecast for next hour
    y_hat = model.forecast()[0]
    # expected value
    y_actual = test[t]
    
    predictions.append(y_hat)
    history.append(y_actual)
    print('predicted=%f, actual=%f' % (y_hat, y_actual))
# Out:
# predicted=88.675478, actual=51.900000
# predicted=38.362100, actual=15.370000
# predicted=4.225387, actual=14.600000
# predicted=15.242568, actual=13.910000
# predicted=13.626915, actual=13.660000
# predicted=13.599120, actual=15.580000
# predicted=16.228157, actual=12.520000
# predicted=11.442467, actual=22.490000
# predicted=25.917203, actual=46.570000
# predicted=54.360390, actual=31.910000
# predicted=26.369147, actual=40.310000
# predicted=43.571748, actual=49.260000
# predicted=51.994778, actual=41.340000
# predicted=38.465742, actual=41.920000
# predicted=42.346560, actual=57.230000
# predicted=62.324517, actual=36.430000
# predicted=29.050278, actual=93.200000
# predicted=112.812324, actual=169.490000
# predicted=193.464139, actual=302.830000
# predicted=345.585156, actual=337.830000
# predicted=346.111282, actual=299.790000
# predicted=286.372231, actual=201.960000
# predicted=170.253685, actual=95.150000
# predicted=61.900814, actual=11.710000

# %% [markdown]
# ## <span style="color:cyan">ARIMA(2,1,1)</span>

# %%
# walk-forward validation
predictions_2 = list()
history = train.copy()
for t in range(len(test)):
    # fit model
    model = ARIMA(history, order=(2,1,1)).fit()
    
    # get forecast for next hour
    y_hat = model.forecast()[0]
    # expected value
    y_actual = test[t]
    
    predictions_2.append(y_hat)
    history.append(y_actual)
    print('predicted=%f, actual=%f' % (y_hat, y_actual))
# Out:
# predicted=82.111538, actual=51.900000
# predicted=41.088972, actual=15.370000
# predicted=12.082886, actual=14.600000
# predicted=25.913226, actual=13.910000
# predicted=25.245221, actual=13.660000
# predicted=25.098469, actual=15.580000
# predicted=27.500270, actual=12.520000
# predicted=22.760900, actual=22.490000
# predicted=36.428229, actual=46.570000
# predicted=62.527846, actual=31.910000
# predicted=34.212308, actual=40.310000
# predicted=50.672635, actual=49.260000
# predicted=58.424972, actual=41.340000
# predicted=44.763051, actual=41.920000
# predicted=48.659403, actual=57.230000
# predicted=67.601767, actual=36.430000
# predicted=35.168912, actual=93.200000
# predicted=114.940038, actual=169.490000
# predicted=187.671207, actual=302.830000
# predicted=324.268294, actual=337.830000
# predicted=314.152716, actual=299.790000
# predicted=252.410222, actual=201.960000
# predicted=145.266835, actual=95.150000
# predicted=51.105479, actual=11.710000

# %% [markdown]
# # Analysis

# %%
# evaluate arima(1,1,1)
rmse = mean_squared_error(test, predictions)**(0.5)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 41.374

# %%
# evaluate arima(2,1,1)
rmse_2 = mean_squared_error(test, predictions_2)**(0.5)
print('Test RMSE: %.3f' % rmse_2)
# Out:
# Test RMSE: 36.057

# %%
# plot predicted vs expected
plt.plot(test, label='actual')
plt.plot(predictions, 'r-', label='arima(1,1,1)')
plt.plot(predictions_2, 'g-', label='arima(2,1,1)')
plt.legend()
plt.show()

# %% [markdown]
# # Long-Term Forecasting

# %% [markdown]
# The ARIMA model is not without limitations. Specifically,
# it can struggle to predict far into the future. Luckily,
# Many other models have been built based off of ARIMA
# to address this deficit.
# ++

# %%
daily_data = df.resample('D').sum()
train = daily_data['HydroElectric']['2017-01-01':'2018-12-31']
test = daily_data['HydroElectric']['2019-01-01':'2019-01-07']

# %%
# fit model
model = ARIMA(train, order=(7,1,1))
model_fit = model.fit()

# %%
# out-of sample forecast
forecast = model_fit.forecast(steps=7)

# %%
# plot forecasts against actual outcomes
plt.plot(test)
plt.plot(forecast, 'r--')
plt.show()
