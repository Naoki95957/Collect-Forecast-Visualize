# %%
import numpy as np
import pandas as pd
import pymongo
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta

# %%
client = pymongo.MongoClient("mongodb+srv://BCWATT:WattTime2021@cluster0.tbh2o.mongodb.net/WattTime?retryWrites=true&w=majority")
energy = {'El_Salvador' : ['Biomass','Geothermal','HydroElectric','Interconnection','Thermal','Solar','Wind'],
          'Costa_Rica' : ['Hydroelectric','Interchange','Other','Solar','Thermal','Wind','Geothermal'],
          'Nicaragua' : ['GEOTHERMAL','HYDRO','INTERCHANGE','SOLAR','THERMAL','WIND']}

# %%
# get data from mongo and reformat into lists
data = {}
test = {}
for country in energy:
    print('Grabbing',country)
    db = client[country]
    coll = db['Historic']
    cursor = coll.find({})
    data[country] = []

    for doc in cursor:
        doc.pop('_id')
        for key in doc:
            hour = [np.nan for x in range(len(energy[country]) + 1)]
            dt = datetime.strptime(key, '%H-%d/%m/%Y')
            hour[0] = dt
            for item in doc[key]:
                i = energy[country].index(item['type']) + 1
                hour[i] = item['value']
            data[country].append(hour)
    
    data[country] = pd.DataFrame(data[country], columns = ['ds'] + energy[country])
    
    data[country] = data[country].drop_duplicates('ds') \
                                 .set_index('ds') \
                                 .resample('H') \
                                 .asfreq()
    data[country] = data[country].fillna(0)
    test[country] = data[country][-168:]
    data[country] = data[country][:-168]
# Out:
# Grabbing El_Salvador
# Grabbing Costa_Rica
# Grabbing Nicaragua

# %% [markdown]
# ## <span style="color:cyan">Data Visualization</span>

# %%
x = datetime(2020, 1, 1, 0)
x
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
delta = x + timedelta(days=6, hours=23)
delta
# Out:
# datetime.datetime(2020, 1, 7, 23, 0)

# %%
for country in data:
    for meta in data[country]:
        data[country][[meta]].plot()

# %%
data['El_Salvador']['Thermal'][-168:].plot()
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
test['El_Salvador']['Thermal'].plot()
# Out:
# <AxesSubplot:xlabel='ds'>

# %% [markdown]
# ## <span style="color:cyan">Data Prep</span>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
thermal = data['El_Salvador']['Thermal']
hydro = data['El_Salvador']['HydroElectric']
solar = data['El_Salvador']['Solar']
geo = data['El_Salvador']['Geothermal']
bio = data['El_Salvador']['Biomass']

# %%
def fuller(X):
    result = adfuller(X)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# %%
# Stationarity
# y(t) = y(t) - y(t-1)

# %%
df = thermal - thermal.shift(1)
df = df[1:]
df.plot()
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
df = df.reset_index()

# %%
df = df.rename(columns = {'ds':'ds', 'Thermal':'y'})

# %% [markdown]
# ## <span style="color:cyan">Make Prediction</span>

# %%
from fbprophet import Prophet

# %%
import copy

# %%
model = Prophet()
model.fit(df)

# %%
future_dates = model.make_future_dataframe(periods=168, freq='h')

# %%
# make a prediction with our model
prediction = model.predict(future_dates)

# %%
result = copy.deepcopy(prediction[-168:]['yhat'])
ds = prediction[-168:]['ds']

# %%
reference = thermal[-1]
result.iloc[0] = reference + result.iloc[0]

# %%
for i in range(1, 168):
    result.iloc[i] = result.iloc[i-1] + result.iloc[i]

# %%
result
# Out:
# 36575     42.375846
# 36576     38.709197
# 36577     36.876763
# 36578     31.626096
# 36579     28.298548
#             ...
# 36738    198.914199
# 36739    190.505049
# 36740    152.326884
# 36741    103.028931
# 36742     64.659375
# Name: yhat, Length: 168, dtype: float64

# %%
result = result.to_frame()
result['ds'] = ds
# Out:
#              yhat                  ds
# 36575   42.375846 2021-02-28 00:00:00
# 36576   38.709197 2021-02-28 01:00:00
# 36577   36.876763 2021-02-28 02:00:00
# 36578   31.626096 2021-02-28 03:00:00
# 36579   28.298548 2021-02-28 04:00:00
# ...           ...                 ...
# 36738  198.914199 2021-03-06 19:00:00
# 36739  190.505049 2021-03-06 20:00:00
# 36740  152.326884 2021-03-06 21:00:00
# 36741  103.028931 2021-03-06 22:00:00
# 36742   64.659375 2021-03-06 23:00:00
#
# [168 rows x 2 columns]

# %%
result = result.set_index('ds')
result
# Out:
#                            yhat
# ds
# 2021-02-28 00:00:00   42.375846
# 2021-02-28 01:00:00   38.709197
# 2021-02-28 02:00:00   36.876763
# 2021-02-28 03:00:00   31.626096
# 2021-02-28 04:00:00   28.298548
# ...                         ...
# 2021-03-06 19:00:00  198.914199
# 2021-03-06 20:00:00  190.505049
# 2021-03-06 21:00:00  152.326884
# 2021-03-06 22:00:00  103.028931
# 2021-03-06 23:00:00   64.659375
#
# [168 rows x 1 columns]

# %%
# check data
# print(prediction[['ds', 'yhat']].iloc[8783:].to_string())

# %%
df2 = thermal.reset_index()
df2 = df2.rename(columns={'Thermal': 'y'})
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-edb4b95546ee> in <module>
# ----> 1 df2 = thermal.reset_index()
#       2 df2 = df2.rename(columns={'Thermal': 'y'})
#       3 df2
#
# NameError: name 'thermal' is not defined

# %%
m2 = Prophet()
m2.fit(df2)

# %%
future_dates = m2.make_future_dataframe(periods=168, freq='h')

# %%
# make a prediction with our model
p2 = m2.predict(future_dates)

# %%
r2 = p2[-168:][['ds', 'yhat']]

# %% [markdown]
# ## <span style="color:cyan">Plot Prediction</span>

# %%
result.plot()
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
test['El_Salvador']['Thermal'].plot()
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
r2.plot()

# %%
# get technical statistical plots
# model.plot_components(prediction)

# %% [markdown]
# ## <span style="color:cyan">Cross Validation</span>

# %%
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics

# %%
cv = cross_validation(model, initial = '30 days', period = '30 days', horizon = '168 hours')
# Out:
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2020-02-28 23:00:00 and 2020-12-24 23:00:00
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
performance = performance_metrics(cv)
performance.head()
# Out:
#           horizon         mse       rmse       mae      mape     mdape  \
# 0 0 days 17:00:00  195.549151  13.983889  9.109358  7.401659  0.511275
# 1 0 days 18:00:00  196.723591  14.025819  9.161858  7.465817  0.514295
# 2 0 days 19:00:00  198.332756  14.083066  9.254810  7.536919  0.556028
# 3 0 days 20:00:00  200.017659  14.142760  9.345618  7.614293  0.569331
# 4 0 days 21:00:00  201.395651  14.191394  9.438133  7.696134  0.588758
#
#    coverage
# 0  0.731225
# 1  0.725791
# 2  0.720356
# 3  0.714921
# 4  0.709486

# %%
# prediciton.

# %%
# y_true starts at predictive hour 768 - 936

cursor = collection.find({'_id': '02/02/2021'})
y_true = {}
doc = cursor.next()
doc.pop('_id')
for key in doc:
    date = datetime.strptime(key, '%H-%d/%m/%Y')
    for value in doc[key]:
        meta = value['type']
        if meta not in y_true.keys():
            print(meta)
            y_true[meta] = []
        y_true[meta].append([date, value['value']])

# %%
for meta in y_true:
    y_true[meta] = pd.DataFrame(y_true[meta],
                                columns=['ds', 'y'])

# %% [markdown]
# ## <span style="color:cyan">Scrap Paper</span>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
series = df['Biomass']
# fit polynomial: x^2*b1 + x*b2 + ... + bn
X = [i%8760 for i in range(0, len(series))]
y = series.values
degree = 4
coef = np.polyfit(X, y, degree)
print('Coefficients: %s' % coef)
# create curve
curve = list()
for i in range(len(X)):
	value = coef[-1]
	for d in range(degree):
		value += X[i]**(degree-d) * coef[d]
	curve.append(value)
# plot curve over original data
plt.plot(series.values)
plt.plot(curve, color='red', linewidth=3)
plt.show()
# Out:
# Coefficients: [-1.19347757e-13  4.06581731e-09 -3.09857704e-05  4.24423666e-02
#   1.22723875e+02]

# %%
# create seasonally adjusted
values = series.values
diff = list()
for i in range(len(values)):
	value = values[i] - curve[i]
	diff.append(value)
plt.plot(diff)
plt.show()
